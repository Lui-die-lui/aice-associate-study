# %%
import pandas as pd

df = pd.read_csv('aice_associate_customer_churn.csv')

# %%
df.head()
# Out:
#   customer_id gender   age     city signup_date plan_type payment_method  \
# 0       C0001      F  42.0    Busan  2025-07-12  Standard           Bank
# 1       C0002      F  31.0    Seoul  2024-01-07  Standard           Card
# 2       C0003      F  38.0  Incheon  2025-04-15  Standard         Mobile
# 3       C0004      M  21.0    Busan  2024-03-22     Basic           Card
# 4       C0005      M  36.0  Incheon  2024-06-24  Standard           Bank
#
#    monthly_usage_hours  support_calls  monthly_fee  satisfaction_score  churn
# 0                 43.4              3         34.8                   1      1
# 1                 25.3              2         33.6                   3      0
# 2                 44.7              0         27.8                   3      0
# 3                 20.0              4         15.0                   3      1
# 4                 50.4              0         33.0                   3      0

# %%
df.shape
# Out:
# (220, 12)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          220 non-null    str
#  1   gender               220 non-null    str
#  2   age                  208 non-null    float64
#  3   city                 211 non-null    str
#  4   signup_date          220 non-null    str
#  5   plan_type            220 non-null    str
#  6   payment_method       220 non-null    str
#  7   monthly_usage_hours  213 non-null    float64
#  8   support_calls        220 non-null    int64
#  9   monthly_fee          220 non-null    float64
#  10  satisfaction_score   220 non-null    int64
#  11  churn                220 non-null    int64
# dtypes: float64(3), int64(3), str(6)
# memory usage: 20.8 KB

# %%
df['age'].isnull().sum()
# Out:
# np.int64(12)

# %%
df.dtypes
# Out:
# customer_id                str
# gender                     str
# age                    float64
# city                       str
# signup_date                str
# plan_type                  str
# payment_method             str
# monthly_usage_hours    float64
# support_calls            int64
# monthly_fee            float64
# satisfaction_score       int64
# churn                    int64
# dtype: object

# %%
df['city'].isnull().sum()
# Out:
# np.int64(9)

# %%
df.describe()
# Out:
#               age  monthly_usage_hours  support_calls  monthly_fee  \
# count  208.000000           213.000000     220.000000   220.000000
# mean    34.168269            39.079812       1.922727    30.374091
# std     10.466674            17.312822       1.555204    13.559570
# min     19.000000             4.700000       0.000000    13.400000
# 25%     27.000000            26.900000       1.000000    18.800000
# 50%     34.000000            38.000000       2.000000    29.600000
# 75%     40.250000            49.000000       3.000000    35.975000
# max    101.000000           145.700000       6.000000    63.900000
#
#        satisfaction_score       churn
# count          220.000000  220.000000
# mean             3.336364    0.263636
# std              1.203323    0.441609
# min              1.000000    0.000000
# 25%              3.000000    0.000000
# 50%              3.000000    0.000000
# 75%              4.000000    1.000000
# max              5.000000    1.000000

# %%
df['city'].value_counts()
# Out:
# city
# Seoul      86
# Busan      58
# Incheon    38
# Daegu      29
# Name: count, dtype: int64

# %%
df['plan_type'].value_counts()
# Out:
# plan_type
# Basic       100
# Standard     81
# Premium      39
# Name: count, dtype: int64

# %%
df['age'] >= 30
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 215    False
# 216     True
# 217    False
# 218    False
# 219     True
# Name: age, Length: 220, dtype: bool

# %%
df[df['age'] >= 30]
# Out:
#     customer_id gender   age     city signup_date plan_type payment_method  \
# 0         C0001      F  42.0    Busan  2025-07-12  Standard           Bank
# 1         C0002      F  31.0    Seoul  2024-01-07  Standard           Card
# 2         C0003      F  38.0  Incheon  2025-04-15  Standard         Mobile
# 4         C0005      M  36.0  Incheon  2024-06-24  Standard           Bank
# 7         C0008      F  30.0    Busan  2025-11-27     Basic           Bank
# ..          ...    ...   ...      ...         ...       ...            ...
# 210       C0211      F  33.0  Incheon  2024-09-22  Standard           Bank
# 212       C0213      M  38.0    Seoul  2024-01-03     Basic           Bank
# 214       C0215      F  42.0  Incheon  2025-04-21   Premium           Card
# 216       C0217      M  47.0    Seoul  2024-12-09  Standard           Card
# 219       C0220      M  31.0      NaN  2025-08-21     Basic           Bank
#
# ...

# %%
df[df['monthly_fee'] >= 30]
# Out:
#     customer_id gender   age     city signup_date plan_type payment_method  \
# 0         C0001      F  42.0    Busan  2025-07-12  Standard           Bank
# 1         C0002      F  31.0    Seoul  2024-01-07  Standard           Card
# 4         C0005      M  36.0  Incheon  2024-06-24  Standard           Bank
# 8         C0009      F  32.0  Incheon  2024-12-14  Standard           Bank
# 9         C0010      F  30.0    Seoul  2024-07-22   Premium           Bank
# ..          ...    ...   ...      ...         ...       ...            ...
# 200       C0201      M  39.0    Busan  2024-10-07  Standard           Card
# 205       C0206      F  43.0    Busan  2025-02-05  Standard           Bank
# 210       C0211      F  33.0  Incheon  2024-09-22  Standard           Bank
# 214       C0215      F  42.0  Incheon  2025-04-21   Premium           Card
# 216       C0217      M  47.0    Seoul  2024-12-09  Standard           Card
#
# ...

# %%
df[(df['age'] >= 30) & (df['support_calls'] >= 3)]
# Out:
#     customer_id gender   age     city signup_date plan_type payment_method  \
# 0         C0001      F  42.0    Busan  2025-07-12  Standard           Bank
# 8         C0009      F  32.0  Incheon  2024-12-14  Standard           Bank
# 9         C0010      F  30.0    Seoul  2024-07-22   Premium           Bank
# 10        C0011      M  30.0      NaN  2024-09-02   Premium         Mobile
# 11        C0012      F  42.0    Seoul  2025-03-09     Basic         Mobile
# 16        C0017      F  52.0    Busan  2025-02-14  Standard           Card
# 19        C0020      F  32.0    Busan  2024-11-19  Standard           Bank
# 28        C0029      M  39.0  Incheon  2024-09-28     Basic         Mobile
# 38        C0039      M  35.0  Incheon  2025-07-13     Basic           Bank
# 42        C0043      M  35.0    Seoul  2024-06-16  Standard           Card
# 63        C0064      M  38.0    Busan  2025-05-16  Standard         Mobile
# ...

# %%
df[(df['plan_type'] == 'Premium') | (df['monthly_fee'] <= 2)]
# Out:
#     customer_id gender   age     city signup_date plan_type payment_method  \
# 9         C0010      F  30.0    Seoul  2024-07-22   Premium           Bank
# 10        C0011      M  30.0      NaN  2024-09-02   Premium         Mobile
# 25        C0026      F  27.0  Incheon  2024-08-30   Premium           Bank
# 30        C0031      M   NaN    Busan  2025-11-13   Premium           Bank
# 35        C0036      M  22.0    Seoul  2024-06-11   Premium           Bank
# 39        C0040      M  31.0  Incheon  2025-02-07   Premium           Bank
# 41        C0042      F  37.0    Daegu  2024-01-21   Premium           Card
# 43        C0044      M  41.0    Seoul  2025-12-14   Premium           Card
# 49        C0050      F  33.0    Daegu  2024-07-15   Premium           Bank
# 55        C0056      F  23.0      NaN  2024-03-14   Premium         Mobile
# 59        C0060      M  34.0    Daegu  2024-01-02   Premium         Mobile
# ...

# %%
df[(df['plan_type'] == 'Premium')|(df['monthly_fee'] <= 20)]
# Out:
#     customer_id gender   age     city signup_date plan_type payment_method  \
# 3         C0004      M  21.0    Busan  2024-03-22     Basic           Card
# 5         C0006      F  27.0    Daegu  2024-11-19     Basic           Card
# 6         C0007      M  19.0    Seoul  2025-07-28     Basic           Card
# 7         C0008      F  30.0    Busan  2025-11-27     Basic           Bank
# 9         C0010      F  30.0    Seoul  2024-07-22   Premium           Bank
# ..          ...    ...   ...      ...         ...       ...            ...
# 209       C0210      M  32.0    Busan  2025-04-09     Basic           Card
# 213       C0214      F  19.0      NaN  2025-03-02     Basic           Card
# 214       C0215      F  42.0  Incheon  2025-04-21   Premium           Card
# 217       C0218      F  19.0  Incheon  2024-02-14     Basic           Card
# 219       C0220      M  31.0      NaN  2025-08-21     Basic           Bank
#
# ...

# %%
df.sort_values('age')
# Out:
#     customer_id gender   age     city signup_date plan_type payment_method  \
# 6         C0007      M  19.0    Seoul  2025-07-28     Basic           Card
# 24        C0025      F  19.0    Seoul  2024-11-11     Basic           Card
# 20        C0021      M  19.0  Incheon  2025-07-30     Basic           Bank
# 17        C0018      M  19.0  Incheon  2024-06-07  Standard           Bank
# 33        C0034      F  19.0    Seoul  2025-02-13  Standard           Card
# ..          ...    ...   ...      ...         ...       ...            ...
# 118       C0119      F   NaN    Seoul  2024-03-09  Standard           Card
# 175       C0176      M   NaN    Seoul  2024-04-15  Standard           Bank
# 197       C0198      M   NaN    Daegu  2025-12-12     Basic           Bank
# 206       C0207      M   NaN  Incheon  2024-11-20     Basic           Card
# 218       C0219      F   NaN    Seoul  2024-03-04     Basic           Bank
#
# ...

# %%
df.sort_values('age', ascending=False)
# Out:
#     customer_id gender    age     city signup_date plan_type payment_method  \
# 14        C0015      F  101.0    Seoul  2025-11-20  Standard           Bank
# 139       C0140      F   61.0    Daegu  2025-05-15  Standard           Bank
# 157       C0158      M   55.0    Seoul  2025-07-24     Basic           Card
# 83        C0084      F   54.0    Seoul  2025-03-30     Basic           Bank
# 64        C0065      M   54.0    Busan  2025-02-24     Basic         Mobile
# ..          ...    ...    ...      ...         ...       ...            ...
# 118       C0119      F    NaN    Seoul  2024-03-09  Standard           Card
# 175       C0176      M    NaN    Seoul  2024-04-15  Standard           Bank
# 197       C0198      M    NaN    Daegu  2025-12-12     Basic           Bank
# 206       C0207      M    NaN  Incheon  2024-11-20     Basic           Card
# 218       C0219      F    NaN    Seoul  2024-03-04     Basic           Bank
#
# ...

# %%
df.sort_values("age", ascending=False).iloc[0]
# Out:
# customer_id                 C0015
# gender                          F
# age                         101.0
# city                        Seoul
# signup_date            2025-11-20
# plan_type                Standard
# payment_method               Bank
# monthly_usage_hours          48.7
# support_calls                   0
# monthly_fee                  33.1
# satisfaction_score              1
# churn                           1
# Name: 14, dtype: object

# %%
df.sort_values("age").iloc[0]
# Out:
# customer_id                 C0007
# gender                          M
# age                          19.0
# city                        Seoul
# signup_date            2025-07-28
# plan_type                   Basic
# payment_method               Card
# monthly_usage_hours          42.9
# support_calls                   0
# monthly_fee                  18.0
# satisfaction_score              3
# churn                           0
# Name: 6, dtype: object

# %%
df.sort_values("age", ascending=False).iloc[0]["customer_id"]
# Out:
# 'C0015'

# %%
df.sort_values("age").iloc[0]["customer_id"]
# Out:
# 'C0007'

# %%
df.loc[df['age']>=30, ['customer_id','age']]
# Out:
#     customer_id   age
# 0         C0001  42.0
# 1         C0002  31.0
# 2         C0003  38.0
# 4         C0005  36.0
# 7         C0008  30.0
# ..          ...   ...
# 210       C0211  33.0
# 212       C0213  38.0
# 214       C0215  42.0
# 216       C0217  47.0
# 219       C0220  31.0
#
# [141 rows x 2 columns]

# %%
df.groupby('plan_type')['monthly_fee'].mean()
# Out:
# plan_type
# Basic       18.657000
# Premium     54.787179
# Standard    33.085185
# Name: monthly_fee, dtype: float64

# %%
df.groupby('plan_type')['monthly_usage_hours'].max()
# Out:
# plan_type
# Basic        56.7
# Premium      86.5
# Standard    145.7
# Name: monthly_usage_hours, dtype: float64

# %%
df.groupby('city')['satisfaction_score'].mean()
# Out:
# city
# Busan      3.120690
# Daegu      3.827586
# Incheon    3.368421
# Seoul      3.313953
# Name: satisfaction_score, dtype: float64

# %%
df[df['age']>=30]
# Out:
#     customer_id gender   age     city signup_date plan_type payment_method  \
# 0         C0001      F  42.0    Busan  2025-07-12  Standard           Bank
# 1         C0002      F  31.0    Seoul  2024-01-07  Standard           Card
# 2         C0003      F  38.0  Incheon  2025-04-15  Standard         Mobile
# 4         C0005      M  36.0  Incheon  2024-06-24  Standard           Bank
# 7         C0008      F  30.0    Busan  2025-11-27     Basic           Bank
# ..          ...    ...   ...      ...         ...       ...            ...
# 210       C0211      F  33.0  Incheon  2024-09-22  Standard           Bank
# 212       C0213      M  38.0    Seoul  2024-01-03     Basic           Bank
# 214       C0215      F  42.0  Incheon  2025-04-21   Premium           Card
# 216       C0217      M  47.0    Seoul  2024-12-09  Standard           Card
# 219       C0220      M  31.0      NaN  2025-08-21     Basic           Bank
#
# ...

# %%
import pandas as pd

df = pd.read_csv('aice_associate_customer_churn.csv')

# %%
df.head()
# Out:
#   customer_id gender   age     city signup_date plan_type payment_method  \
# 0       C0001      F  42.0    Busan  2025-07-12  Standard           Bank
# 1       C0002      F  31.0    Seoul  2024-01-07  Standard           Card
# 2       C0003      F  38.0  Incheon  2025-04-15  Standard         Mobile
# 3       C0004      M  21.0    Busan  2024-03-22     Basic           Card
# 4       C0005      M  36.0  Incheon  2024-06-24  Standard           Bank
#
#    monthly_usage_hours  support_calls  monthly_fee  satisfaction_score  churn
# 0                 43.4              3         34.8                   1      1
# 1                 25.3              2         33.6                   3      0
# 2                 44.7              0         27.8                   3      0
# 3                 20.0              4         15.0                   3      1
# 4                 50.4              0         33.0                   3      0

# %%
df.loc[df['age']>=30, 'monthly_fee'].mean()
# Out:
# np.float64(31.487943262411356)

# %%
df['age'].fillna(0)
# Out:
# 0      42.0
# 1      31.0
# 2      38.0
# 3      21.0
# 4      36.0
#        ...
# 215    27.0
# 216    47.0
# 217    19.0
# 218     0.0
# 219    31.0
# Name: age, Length: 220, dtype: float64

# %%
df['age'].fillna(df['age'].mean())
# Out:
# 0      42.000000
# 1      31.000000
# 2      38.000000
# 3      21.000000
# 4      36.000000
#          ...
# 215    27.000000
# 216    47.000000
# 217    19.000000
# 218    34.168269
# 219    31.000000
# Name: age, Length: 220, dtype: float64

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df['age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['age'].median()
# Out:
# np.float64(34.16826923076923)

# %%
df['city'].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df['city'].mean()
#
# File ~\Desktop\AICE\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File ~\Desktop\AICE\.venv\Lib\site-packages\pandas\core\series.py:8113, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    8063 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#    8064 def mean(
#    8065     self,
#    (...)   8069     **kwargs,
#    8070 ) -> Any:
#    8071     """
# ...

# %%
df['city'].mode()
# Out:
# 0    Seoul
# Name: city, dtype: str

# %%
df.['city'].mode()[0]
# Out:
#   Cell In[20], line 1
#     df.['city'].mode()[0]
#        ^
# SyntaxError: invalid syntax

# %%
df["city"].mode()[0]
# Out:
# 'Seoul'

# %%
df['city'].mode()[0]
# Out:
# 'Seoul'

# %%
df['city'].isnull().sum()
# Out:
# np.int64(9)

# %%
df['city'].fillna(df['city'].mode()[0])
# Out:
# 0        Busan
# 1        Seoul
# 2      Incheon
# 3        Busan
# 4      Incheon
#         ...
# 215      Seoul
# 216      Seoul
# 217    Incheon
# 218      Seoul
# 219      Seoul
# Name: city, Length: 220, dtype: str

# %%
df['city'] = df['city'].fillna(df['city'].mode()[0])

# %%
df['city'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['monthly_usage_hours'] = df['monthly_usage_hours'].fillna(df['monthly_usage_hours'].median())

# %%
df['monthly_usage_hours'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#               age  monthly_usage_hours  support_calls  monthly_fee  \
# count  220.000000           220.000000     220.000000   220.000000
# mean    34.168269            39.045455       1.922727    30.374091
# std     10.175876            17.034945       1.555204    13.559570
# min     19.000000             4.700000       0.000000    13.400000
# 25%     27.750000            26.975000       1.000000    18.800000
# 50%     34.168269            38.000000       2.000000    29.600000
# 75%     40.000000            48.900000       3.000000    35.975000
# max    101.000000           145.700000       6.000000    63.900000
#
#        satisfaction_score       churn
# count          220.000000  220.000000
# mean             3.336364    0.263636
# std              1.203323    0.441609
# min              1.000000    0.000000
# 25%              3.000000    0.000000
# 50%              3.000000    0.000000
# 75%              4.000000    1.000000
# max              5.000000    1.000000

# %%
df.dropna(subset=['age'])
# Out:
#     customer_id gender        age     city signup_date plan_type  \
# 0         C0001      F  42.000000    Busan  2025-07-12  Standard
# 1         C0002      F  31.000000    Seoul  2024-01-07  Standard
# 2         C0003      F  38.000000  Incheon  2025-04-15  Standard
# 3         C0004      M  21.000000    Busan  2024-03-22     Basic
# 4         C0005      M  36.000000  Incheon  2024-06-24  Standard
# ..          ...    ...        ...      ...         ...       ...
# 215       C0216      M  27.000000    Seoul  2025-05-20  Standard
# 216       C0217      M  47.000000    Seoul  2024-12-09  Standard
# 217       C0218      F  19.000000  Incheon  2024-02-14     Basic
# 218       C0219      F  34.168269    Seoul  2024-03-04     Basic
# 219       C0220      M  31.000000    Seoul  2025-08-21     Basic
#
#     payment_method  monthly_usage_hours  support_calls  monthly_fee  \
# 0             Bank                 43.4              3         34.8
# ...

# %%
df.isnull().sum()
# Out:
# customer_id            0
# gender                 0
# age                    0
# city                   0
# signup_date            0
# plan_type              0
# payment_method         0
# monthly_usage_hours    0
# support_calls          0
# monthly_fee            0
# satisfaction_score     0
# churn                  0
# dtype: int64

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.info()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv('aice_associate_customer_churn.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          220 non-null    str
#  1   gender               220 non-null    str
#  2   age                  208 non-null    float64
#  3   city                 211 non-null    str
#  4   signup_date          220 non-null    str
#  5   plan_type            220 non-null    str
#  6   payment_method       220 non-null    str
#  7   monthly_usage_hours  213 non-null    float64
#  8   support_calls        220 non-null    int64
#  9   monthly_fee          220 non-null    float64
#  10  satisfaction_score   220 non-null    int64
#  11  churn                220 non-null    int64
# dtypes: float64(3), int64(3), str(6)
# memory usage: 20.8 KB
