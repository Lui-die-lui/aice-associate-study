# %%
# 피벗테이블 생성
import numpy as np
import pandas as pd

pivot_data = pd.DataFrame({'cust_id':['cust_1', 'cust_1', 'cust_1', 'cust_2', 'cust_2', 'cust_2', 'cust_3', 'cust_3', 'cust_3'],
                           'prod_cd':['p1', 'p2', 'p3', 'p1', 'p2', 'p3', 'p1', 'p2', 'p3' ],
                           'grade':['A', 'A', 'A', 'A', 'A', 'A', 'B', 'B', 'B'],
                           'purch_amt':[30, 10, 0, 40, 15, 30, 0, 0, 10]})
pivot_data
# Out:
#   cust_id prod_cd grade  purch_amt
# 0  cust_1      p1     A         30
# 1  cust_1      p2     A         10
# 2  cust_1      p3     A          0
# 3  cust_2      p1     A         40
# 4  cust_2      p2     A         15
# 5  cust_2      p3     A         30
# 6  cust_3      p1     B          0
# 7  cust_3      p2     B          0
# 8  cust_3      p3     B         10

# %%
# pivot  활용하기
# pivot은 기본적으로 index, columns, values를 지정하여 구성할 수 있다

pivot1 = pivot_data.pivot(index='cust_id', columns='prod_cd', values='purch_amt')
pivot1
# Out:
# prod_cd  p1  p2  p3
# cust_id
# cust_1   30  10   0
# cust_2   40  15  30
# cust_3    0   0  10

# %%
# 중복값이 존재하는 경우 pivot 사용 불가 
# 예를 들어 A행 p1 열에 100, 200 같은 값이 2개나 있을때 - 칸은 하나라서 오류
pivot_data.pivot(index='grade', columns='prod_cd', values='purch_amt')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 # 중복값이 존재하는 경우 pivot 사용 불가
# ----> 2 pivot_data.pivot(index='grade', columns='prod_cd', values='purch_amt')
#
# File ~\Desktop\AICE\.venv\Lib\site-packages\pandas\core\frame.py:10988, in DataFrame.pivot(self, columns, index, values)
#   10981 @Substitution("")
#   10982 @Appender(_shared_docs["pivot"])
#   10983 def pivot(
#   10984     self, *, columns, index=lib.no_default, values=lib.no_default
#   10985 ) -> DataFrame:
#   10986     from pandas.core.reshape.pivot import pivot
# > 10988     return pivot(self, index=index, columns=columns, values=values)
#
# File ~\Desktop\AICE\.venv\Lib\site-packages\pandas\core\reshape\pivot.py:910, in pivot(data, columns, index, values)
#     905         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     906 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     907 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     908 # "Hashable"
#     909 # unstack with a MultiIndex returns a DataFrame
# --> 910 result = cast("DataFrame", indexed.unstack(columns_listlike))  # type: ignore[arg-type]
#     911 result.index.names = [
#     912     name if name is not lib.no_default else None for name in result.index.names
#     913 ]
#     915 return result
#
# File ~\Desktop\AICE\.venv\Lib\site-packages\pandas\core\series.py:4501, in Series.unstack(self, level, fill_value, sort)
#    4451 """
#    4452 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4453
#    (...)   4497 b    2    4
#    4498 """
#    4499 from pandas.core.reshape.reshape import unstack
# -> 4501 return unstack(self, level, fill_value, sort)
#
# File ~\Desktop\AICE\.venv\Lib\site-packages\pandas\core\reshape\reshape.py:596, in unstack(obj, level, fill_value, sort)
#     594 if is_1d_only_ea_dtype(obj.dtype):
#     595     return _unstack_extension_series(obj, level, fill_value, sort=sort)
# --> 596 unstacker = _Unstacker(
#     597     obj.index, level=level, constructor=obj._constructor_expanddim, sort=sort
#     598 )
#     599 return unstacker.get_result(obj, value_columns=None, fill_value=fill_value)
#
# File ~\Desktop\AICE\.venv\Lib\site-packages\pandas\core\reshape\reshape.py:176, in _Unstacker.__init__(self, index, level, constructor, sort)
#     168     if num_cells > np.iinfo(np.int32).max:
#     169         warnings.warn(
#     170             f"The following operation may generate {num_cells} cells "
#     171             f"in the resulting pandas object.",
#     172             PerformanceWarning,
#     173             stacklevel=find_stack_level(),
#     174         )
# --> 176 self._make_selectors()
#
# File ~\Desktop\AICE\.venv\Lib\site-packages\pandas\core\reshape\reshape.py:232, in _Unstacker._make_selectors(self)
#     229 mask.put(selector, True)
#     231 if mask.sum() < len(self.index):
# --> 232     raise ValueError("Index contains duplicate entries, cannot reshape")
#     234 self.group_index = comp_index
#     235 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
# 피벗 테이블 - 위 에러를 반환하는게 아닌 컬럼들의 평균 값을 내버림
pivot_data.pivot_table(index='grade', columns='prod_cd', values='purch_amt')
# Out:
# prod_cd    p1    p2    p3
# grade
# A        35.0  12.5  15.0
# B         0.0   0.0  10.0

# %%
# aggfunc의 기본이 평균값이라 위에서 평균값이 나옴. 다르게 지정도 가능
pivot_data.pivot_table(index='grade', columns='prod_cd', values='purch_amt', aggfunc=np.sum)
# Out:
# prod_cd  p1  p2  p3
# grade
# A        70  25  30
# B         0   0  10
